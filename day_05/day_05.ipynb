# %% [markdown]
# ![1_Xp6UD3MOtkvm9Dml4rDN7A.png](attachment:1_Xp6UD3MOtkvm9Dml4rDN7A.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("decision_tree_regression_dataset.csv", sep=";", header=None)
df.head()
# Out:
#    0    1
# 0  1  100
# 1  2   80
# 2  3   70
# 3  4   60
# 4  5   50

# %%
x = df.iloc[:,0].values.reshape(-1,1)
y = df.iloc[:,1].values.reshape(-1,1)

# %%
#decision tree regression
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor() #randon state = 0
tree_reg.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
tree_reg.predict([[5.6]])
# Out:
# array([40.])

# %%
x_ = np.arange(min(x), max(x), 0.01).reshape(-1,1)
y_head = tree_reg.predict(x_)

# %%
plt.scatter(x, y, color="r")
plt.plot(x_, y_head, color="g")
plt.xlabel("trubin level")
plt.ylabel("odeme")
plt.show()
