# %% [markdown]
# 1. image alınır
# 2. pixeller array'e dönüştürülür
# 3. array'ler weighth ile çarpılır
# 4. sonuç toplanır ve bias ile toplanır
# 5. sonuç sigmoid function' a sokulur
# 6. y_head elde edilir

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# cost = hatalar toplamı (cost verilen parametrelere bağlıdır) cost minimum olmalıdır. <br>
# weight değiştirilmelidir. (w:= w - step) step = slope (slope eğimdir)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Grafiğin bir noktaya göre türev alınırsa o noktanın eğimi bulunur. <br>
