# %%
import pandas as pd

# %%
linear_regression_dataset = pd.read_csv("linear_regression_dataset.csv", sep=";") # sep=";"
df = pd.DataFrame(linear_regression_dataset, columns = ["deneyim","maas"],)

# %%
linear_regression_dataset.head()
# Out:
#    deneyim  maas
# 0      0.5  2500
# 1      0.0  2250
# 2      1.0  2750
# 3      5.0  8000
# 4      8.0  9000

# %%
import matplotlib.pyplot as plt
plt.scatter(df.deneyim, df.maas, c = 'g',marker = ".")
plt.xlabel("deneyim")
plt.ylabel("maas")
plt.show()

# %% [markdown]
# line fit, linear regression <br>
# y = b0 + (b1*x)<br>
# b0=constant(bias)(y exsenini kesen nokta), b1=coeff<br>
# maas = b0 + (b1 * deneyim)<br>
# 12500 = 2500 + (1000 * 10)<br>
# <br>
# deneyim = 11 ==> maas = ?<br>
# maas = b0 + (b1 * x)<br>
# 2500 + (1000 * 11) = 13500<br>

# %% [markdown]
# ![indir.png](attachment:indir.png)

# %% [markdown]
# residual = y - y_head<br>
# mse = sum(residual^2) / n <br>
# n = sample sayısı<br>
# mse = mean squared error<br>
#
# örneklere en uygun line'ı fit ederiz (min mse)<br>
# mse'e de en uygun b0 ve b1 değerini bulmamız gerekiyor<br>

# %% [markdown]
# ![hmZydSW9YegiMVPWq2JBpOpai3CejzQpGkNG.gif](attachment:hmZydSW9YegiMVPWq2JBpOpai3CejzQpGkNG.gif)
